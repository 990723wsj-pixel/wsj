# %%
# 모듈 패키지

# 모듈(책 1권)
# - python 코드(.py 파일)를 하나의 단위로 묶은 것
# import math_tools

# 패키지(책 여러 권이 들어 있는 책장 1칸)
# - 여러 개의 모듈을 폴더로 묶어 놓은 것
# mypackage
# - __init__.py
# - math_tools.py
# - string_tools.py

# from mypackage import math_tools

# %%
import ex1

ex1.funA()
# Out:
# 'A 실행'

# %%
from ex1 import funA, funB

# funA()
# funB()
# 이런식으로 호출하면 마지막 것만 출력
# 안 되는 경우 vscode를 껐다 다시 키면 됨

print(funA())
print(funB())
# Out:
# A 실행
# B 실행

# %%
import sys
print(sys.path)

# 파이썬 모듈 찾는 경로
# Out:
# ['c:\\Users\\202-1354\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\202-1354\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\202-1354\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\202-1354\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\202-1354\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\202-1354\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages']
